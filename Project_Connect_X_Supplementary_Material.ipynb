# %% [markdown]
# # Supplementary Material for our project - Connect X

# %% [markdown]
# ### Authors: Anay Bhat, Brandon Lam, Jhon Garcia

# %% [markdown]
# Information about Kaggle.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('jbRNGuz3IRM')

# %% [markdown]
# ### Kaggle Competition - Connect X

# %% [markdown]
# https://www.kaggle.com/competitions/connectx/overview

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Visualization of the game - Connect X

# %% [markdown]
# ![image.png](data:image/png;base64,...)
